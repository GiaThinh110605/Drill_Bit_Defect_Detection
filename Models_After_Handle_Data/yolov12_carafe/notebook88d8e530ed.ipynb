# %%
import matplotlib.pyplot as plt
import albumentations as A
from pathlib import Path
import yaml
import os
from collections import Counter
import pandas as pd
import random
import cv2
import matplotlib.patches as patches
import numpy as np
# !pip3 install ultralytics
from ultralytics import YOLO
import ultralytics.nn.modules as modules
import ultralytics.nn.tasks as tasks
import torch.nn as nn
import torch.nn.functional as F
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.116-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.29.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.595.45)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.116-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.116 ultralytics-thop-2.1.6
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Khi up lên kaggle nên cần cấu hình lên file yaml
yaml_content = """
path: /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format

train: train/images
val: valid/images
test: 
  - test/Bright_Field/images
  - test/Dark_Field/images

nc: 5

names:
  - Broken
  - Chipped
  - Scratched
  - Severe_Rust
  - Tip_Wear
"""

with open("/kaggle/working/data.yaml", "w") as f:
    f.write(yaml_content)

print("Đã tạo file data.yaml tại /kaggle/working/")
# Out:
# Đã tạo file data.yaml tại /kaggle/working/

# %% [markdown]
# # 1. Kiểm tra dữ liệu có số lượng dataset và tên classes

# %%
# DATASET_PATH = Path("/Users/mac/Detect_Drill_Bit/final-dataset")
DATASET_PATH = Path("/kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format")
DATA_YAML = "data.yaml"

with open(DATA_YAML, 'r') as f:
    data_config = yaml.safe_load(f)

CLASS_NAMES = data_config["names"]
NUM_CLASSES = data_config["nc"]

print(CLASS_NAMES)
print(NUM_CLASSES)
# Out:
# ['Broken', 'Chipped', 'Scratched', 'Severe_Rust', 'Tip_Wear']
# 5

# %% [markdown]
# # 2. Đếm dữ liệu cho từng bộ dữ liệu

# %%
def check_dataset():
    total_images = 0
    total_labels = 0
    for split in ["train", "valid", "test/Bright_Field", "test/Dark_Field"]:
        img_path = DATASET_PATH / split / 'images'
        label_path = DATASET_PATH / split / 'labels'
        
        # glob dùng để tìm kiếm file, * là tìm kiếm tất cả, ? khớp với ký tự bất kỳ, [seq]: khớp với bất kỳ ký tự nào trong ngoặc vuông
        # suffix dùng để lấy đuôi file
        # đếm ảnh
        images = [f for f in img_path.glob("*") if f.suffix.lower() in [".jpg", ".png", ".png"]]
        num_images = print(f"images trong tập {split}", len(images))

        labels = list(label_path.glob("*.txt"))
        print(f"labels trong tập {split}", len(labels))        
        
        total_images += len(images)
        total_labels += len(labels)
    return total_images, total_labels

total_images, total_labels = check_dataset()
print("Tổng số lượng ảnh: ", total_images)
print("Tổng số lượng labels: ", total_labels)
# Out:
# images trong tập train 4364
# labels trong tập train 3597
# images trong tập valid 844
# labels trong tập valid 706
# images trong tập test/Bright_Field 352
# labels trong tập test/Bright_Field 545
# images trong tập test/Dark_Field 352
# labels trong tập test/Dark_Field 549
# Tổng số lượng ảnh:  5912
# Tổng số lượng labels:  5397

# %% [markdown]
# # 3. Phân tích labels

# %%
def analyze_labels():
    class_counts = Counter()
    total_boxes = 0
    total_labels = 0

    for split in ["train", "val", "test/Bright_Field", "test/Dark_Field"]:
        label_path = DATASET_PATH / split / "labels"
        label_files = list(label_path.glob("*.txt"))

        for label_file in label_files:
            with open(label_file, "r") as f:
                for line in f:
                    parts = line.strip().split()
                    class_id = int(parts[0])
                    class_counts[class_id] += 1
                    total_boxes += 1
    return class_counts, total_boxes
class_counts, total_boxes = analyze_labels()
print(class_counts, total_boxes)
# Out:
# Counter({2: 1770, 3: 1671, 1: 1352, 4: 1119, 0: 1057}) 6969

# %% [markdown]
# # 4. Visualize Phân Bố Dữ Liệu

# %%
def visualize_class_distribution():
    names = []
    counts = []
    for class_id in range(NUM_CLASSES):
        names.append(CLASS_NAMES[class_id])
        counts.append(class_counts[class_id])
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    axes[0, 0].bar(names, counts)
    axes[0, 0].set_title("Phân phối các lớp lỗi")

    axes[0, 1].barh(names, counts)
    axes[0, 1].set_title("Phân phối các lớp lỗi")

    axes[1, 0].pie(counts, labels=names)
    axes[1, 0].set_title("Phân phối các lớp lỗi")

    axes[1, 1].scatter(names, counts)
    axes[1, 1].set_title("Biểu đồ cột phân phối số lượng")


    plt.show()
visualize_class_distribution()

# %% [markdown]
# # 5. Train Model YOLOv12

# %%
class CARAFE(nn.Module):
    def __init__(self, c1, scale_factor=2, k_encoder=3, up_kernel=3):
        super(CARAFE, self).__init__()
        self.scale_factor = scale_factor
        self.up_kernel = up_kernel
        self.k_encoder = k_encoder
        self.down = nn.Conv2d(c1, c1 // 4, 1)
        self.encoder = nn.Conv2d(c1 // 4, self.up_kernel ** 2 * self.scale_factor ** 2, 
                                 self.k_encoder, padding=self.k_encoder // 2)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        N, C, H, W = x.size()
        kernel_tensor = self.down(x)
        kernel_tensor = self.encoder(kernel_tensor)
        kernel_tensor = F.pixel_shuffle(kernel_tensor, self.scale_factor)
        kernel_tensor = self.softmax(kernel_tensor)
        
        x = F.interpolate(x, scale_factor=self.scale_factor, mode='nearest')
        x_unfold = F.unfold(x, self.up_kernel, padding=self.up_kernel // 2)
        
        x_unfold = x_unfold.view(N, C, self.up_kernel**2, -1)
        kernel_tensor = kernel_tensor.view(N, 1, self.up_kernel**2, -1)
        
        out = (x_unfold * kernel_tensor).sum(dim=2)
        out = out.view(N, C, H * self.scale_factor, W * self.scale_factor)
        return out

# 2. Đăng ký module
setattr(modules, 'CARAFE', CARAFE)
setattr(tasks, 'CARAFE', CARAFE)

# 3. File YAML với số kênh đã tính toán cho bản N (scale 0.25)
yaml_content = '''
nc: 5
scales:
  n: [0.50, 0.25, 1024]

backbone:
  - [-1, 1, Conv, [64, 3, 2]] 
  - [-1, 1, Conv, [128, 3, 2]] 
  - [-1, 2, C3k2, [256, False, 0.25]]
  - [-1, 1, Conv, [256, 3, 2]] 
  - [-1, 2, C3k2, [512, False, 0.25]]
  - [-1, 1, Conv, [512, 3, 2]] 
  - [-1, 4, A2C2f, [512, True, 4]]
  - [-1, 1, Conv, [1024, 3, 2]] 
  - [-1, 4, A2C2f, [1024, True, 1]] 

head:
  - [-1, 1, CARAFE, [256, 2]] # 256 là số kênh đầu vào (1024 * 0.25)
  - [[-1, 6], 1, Concat, [1]] 
  - [-1, 2, A2C2f, [512, False, -1]] 

  - [-1, 1, CARAFE, [128, 2]] # 128 là số kênh đầu vào (512 * 0.25)
  - [[-1, 4], 1, Concat, [1]] 
  - [-1, 2, A2C2f, [256, False, -1]] 

  - [-1, 1, Conv, [256, 3, 2]]
  - [[-1, 11], 1, Concat, [1]] 
  - [-1, 2, A2C2f, [512, False, -1]] 

  - [-1, 1, Conv, [512, 3, 2]]
  - [[-1, 8], 1, Concat, [1]] 
  - [-1, 2, C3k2, [1024, True]] 

  - [[14, 17, 20], 1, Detect, [nc]] 
'''

with open('yolov12n-carafe.yaml', 'w') as f:
    f.write(yaml_content)

# %%
model = YOLO("yolov12n-carafe.yaml").load("yolo12n.pt")
results = model.train(
    data='data.yaml', 
    epochs=300, 
    batch=16, 
    workers=4, 
    rect=False,              # Tắt rect để Mosaic 1.0 phát huy 100% tác dụng
    amp=True,

    # --- Tối ưu hóa lỗi Localization (Loc) ---
    imgsz=640, 
    box=9.5,
    dfl=2.0,

    # --- Tối ưu hóa lỗi Background (Bkg) ---
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    mosaic=1.0,
    mixup=0.1,               # Bật mixup nhẹ để khử nhiễu nền
    
    # --- Phép biến đổi khác ---
    scale=0.3,
    fliplr=0.5,
    flipud=0.5,
    erasing=0.05,
    copy_paste=0,
    close_mosaic=20,
    
    # --- Hyperparameters ---
    warmup_epochs=5,
    weight_decay=0.0005,
    patience=40,
    lr0=0.001,
    lrf=0.1,
    cos_lr=True,
    optimizer="AdamW"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo12n.pt to 'yolo12n.pt': 100% ━━━━━━━━━━━━ 5.3MB 62.7MB/s 0.1s
# Transferred 640/699 items from pretrained weights
# Ultralytics 8.4.116 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=9.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=20, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=, dfl=2.0, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=300, erasing=0.05, exist_ok=False, fliplr=0.5, flipud=0.5, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.1, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov12n-carafe.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=40, perspective=0.0, plots=True, pose=12.0, pretrained=yolo12n.pt, profile=False, project=None, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.3, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.1MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1     37220  CARAFE                                       [256, 2]
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1     14532  CARAFE                                       [128, 2]
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    431647  ultralytics.nn.modules.head.Detect           [5, 16, None, [64, 128, 256]]
# YOLOv12n-carafe summary: 276 layers, 2,620,775 parameters, 2,620,759 gradients, 7.5 GFLOPs
#
# Transferred 699/699 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 58.5MB/s 0.1s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 1.2±0.9 ms, read: 2.2±0.5 MB/s, size: 11.6 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format/train/labels... 3521 images, 843 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4364/4364 330.2it/s 13.2s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format/train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 2.2±0.3 MB/s, size: 12.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format/valid/labels... 706 images, 138 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 844/844 232.6it/s 3.6s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format/valid is not writable, cache not saved.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 113 weight(decay=0.0), 124 weight(decay=0.0005), 123 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/train
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      4.49G      2.816       3.54      2.763         27        640: 100% ━━━━━━━━━━━━ 273/273 3.0it/s 1:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 2.2it/s 12.4s
#                    all        844        959      0.167      0.362      0.135     0.0481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300      4.54G      2.644      3.008      2.622         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.6it/s 7.5s
#                    all        844        959      0.119      0.287      0.103     0.0329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300      4.52G      2.633      2.853      2.598         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.354      0.319      0.248     0.0942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300      4.54G      2.586      2.773      2.593         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.7it/s 7.3s
#                    all        844        959      0.243      0.404      0.219     0.0776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      4.54G      2.554      2.688      2.542         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959      0.405      0.385      0.337      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      4.54G      2.497      2.613      2.513         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959      0.416      0.404      0.367      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300      4.52G      2.486      2.544      2.478         13        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959      0.317      0.412      0.313       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      4.54G      2.462      2.497      2.458         16        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.407      0.445      0.387      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      4.54G      2.415      2.475      2.446         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.486      0.474      0.458      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      4.52G      2.411      2.404      2.412         18        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.412      0.476      0.389      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      4.54G      2.363      2.357      2.384         18        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.435      0.446      0.414      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      4.52G      2.363      2.325      2.366         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.524      0.475      0.477      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      4.54G      2.323      2.323      2.361         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.532      0.461      0.487      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      4.54G      2.315      2.286      2.344         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.479      0.527      0.462      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300      4.54G      2.314      2.271      2.334         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.588      0.525       0.56      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300      4.54G        2.3      2.227      2.318         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.552      0.512       0.52       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300      4.52G      2.282      2.198        2.3         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.486      0.474      0.471      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300      4.54G      2.297      2.189      2.298         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.562      0.538      0.554      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300      4.54G      2.272      2.166      2.298         10        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.631      0.577      0.608      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      4.54G      2.267      2.143      2.288         24        640: 100% ━━━━━━━━━━━━ 273/273 3.8it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959       0.57      0.532      0.543      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300      4.52G      2.259      2.114      2.277         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.555      0.581       0.57      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300      4.54G      2.259       2.13      2.284         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.617      0.583      0.607      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300      4.54G      2.233      2.082      2.265         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.626       0.56      0.597      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300      4.52G      2.228      2.077      2.265         30        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.612      0.555      0.607      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300      4.54G      2.226      2.052      2.252         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.598      0.511      0.555      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300      4.52G      2.197      2.002      2.222         18        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.653      0.589      0.641      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300      4.54G      2.188      2.011      2.226         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.663      0.594      0.652      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300      4.54G       2.18      1.987      2.224         30        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.603      0.596        0.6      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300      4.54G      2.198      2.001      2.226         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.629      0.591      0.627      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300      4.52G      2.163       1.99      2.219         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.565      0.611      0.621      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300      4.54G      2.186      1.982      2.224         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.687      0.629      0.689      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300      4.54G       2.16      1.925      2.188         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.631      0.624      0.629      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300      4.52G      2.173       1.92      2.201         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.657      0.609      0.645      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300      4.54G      2.167      1.927      2.209         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959       0.63      0.633      0.637      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300      4.54G      2.149      1.914      2.172         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.683      0.628      0.678      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      4.54G      2.138      1.892      2.164         29        640: 100% ━━━━━━━━━━━━ 273/273 3.8it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.604      0.612      0.644      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      4.54G      2.137      1.887      2.168         16        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.686      0.622      0.663      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      4.52G      2.138      1.871      2.165         13        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.694      0.618      0.676      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      4.52G      2.128      1.864      2.169         15        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.711      0.637      0.705      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300      4.52G      2.102      1.847      2.152         15        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.628      0.625      0.656      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300      4.54G      2.126       1.89      2.165         15        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.697      0.653      0.699      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      4.52G      2.116      1.839      2.156         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.682      0.633      0.689      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      4.54G      2.111      1.841      2.138         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.744      0.636      0.708      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      4.52G      2.096      1.837      2.154         28        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.677       0.67      0.723       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300      4.54G      2.089      1.778      2.135         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.691      0.674      0.714      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300      4.54G      2.102      1.801       2.15         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959       0.73      0.664      0.733      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      4.54G      2.111       1.81      2.147         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.694      0.691      0.734      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300      4.54G      2.086      1.787      2.135         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.748      0.664       0.73      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      4.54G      2.077      1.778      2.126         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959      0.694      0.656       0.71      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300      4.54G      2.118       1.78      2.153         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.732       0.67       0.74      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      4.54G      2.061      1.737      2.114         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.742      0.701      0.747      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300      4.54G      2.074      1.763       2.12         33        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.687      0.702       0.73      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      4.54G      2.072      1.735       2.11         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959        0.7      0.645      0.699      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      4.54G      2.076      1.738      2.097         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.717       0.66      0.713      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      4.52G       2.05      1.704      2.086         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.749      0.653      0.731      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      4.54G      2.049      1.727      2.094         30        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959       0.71      0.649      0.709      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/300      4.54G      2.056      1.725      2.097         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959       0.73      0.692      0.746      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/300      4.54G      2.055       1.72      2.096         18        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.744      0.663       0.74      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/300      4.54G      2.047      1.699      2.083         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.739      0.657      0.734      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/300      4.52G      2.048      1.667      2.091          9        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.717      0.707      0.752      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/300      4.54G      2.035      1.677      2.065         38        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.764      0.688       0.77      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/300      4.54G      2.035      1.677      2.079         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.695      0.699      0.742      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/300      4.54G      2.012       1.63      2.058         16        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.746      0.694      0.766      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/300      4.54G      2.018      1.664      2.063         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.781      0.687      0.784      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/300      4.54G       2.04      1.658      2.089         15        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.759      0.684      0.764      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/300      4.54G      2.025      1.665      2.071         31        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.737      0.681      0.755      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/300      4.54G      2.015      1.633      2.051         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.704      0.715      0.761      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/300      4.54G      1.993      1.608      2.041         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959       0.76      0.716       0.78      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/300      4.54G      2.019      1.638      2.058         33        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.795      0.689      0.768      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/300      4.54G      2.002      1.598       2.05         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.773      0.698      0.768      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/300      4.54G      1.996      1.598      2.043         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.769      0.706      0.771      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/300      4.54G      2.001      1.609      2.043         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.753      0.697      0.763      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/300      4.54G      2.014      1.624      2.069         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.747       0.69      0.756      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/300      4.54G      1.981       1.58       2.03         34        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.729      0.722      0.777      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/300      4.54G      2.004      1.598      2.037         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959       0.76      0.687       0.76      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/300      4.54G      1.992      1.568      2.035         14        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.7it/s 7.2s
#                    all        844        959      0.799      0.672      0.773      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/300      4.52G      1.988      1.578      2.027         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.773      0.725      0.783      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/300      4.54G      1.975      1.585      2.027         28        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.777      0.699      0.775      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/300      4.54G      1.967      1.549      2.022         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.774      0.719      0.783      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/300      4.54G      1.974      1.548      2.023         30        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959       0.77      0.724      0.797      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/300      4.54G      1.962      1.566      2.031         31        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959      0.758      0.717      0.781      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/300      4.56G      1.992      1.575      2.034         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959      0.801      0.731        0.8      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/300      4.54G       1.97      1.529      2.035         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.776       0.71      0.786      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/300      4.52G       1.96      1.544       2.02         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.734      0.731      0.776      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/300      4.52G      1.963      1.536      2.021         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.802      0.686      0.786      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/300      4.54G      1.958      1.509      2.014         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.803      0.703      0.799      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/300      4.52G      1.951      1.494      2.017         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.785      0.708      0.784       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/300      4.54G      1.967      1.514      2.011         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.773       0.71      0.793      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/300      4.54G      1.953      1.514      2.016         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.788      0.715      0.801      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/300      4.54G      1.933      1.485      1.991         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.826      0.689        0.8      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/300      4.54G      1.952       1.49      1.998         29        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.758      0.725      0.791      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/300      4.54G      1.945      1.496      2.009         16        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.779      0.712      0.792      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/300      4.54G      1.935       1.48      1.992         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.765      0.709      0.789       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/300      4.54G      1.948      1.496      2.002         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.774      0.717      0.789      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/300      4.54G      1.927      1.469      1.985         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.779      0.716      0.792      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/300      4.54G      1.925      1.468      1.981         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.773      0.719      0.788      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/300      4.54G       1.92      1.437      1.974         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.748       0.74      0.787      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/300      4.54G      1.903      1.426      1.976         18        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.777      0.703      0.774      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/300      4.52G      1.908      1.453      1.974         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.786      0.713      0.792      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/300      4.54G      1.914      1.438      1.976         15        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     133/300      4.52G      1.837      1.291      1.911         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.745      0.755      0.793      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/300      4.52G      1.787       1.27      1.872         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.759       0.77      0.807      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/300      4.54G      1.814      1.265      1.888         36        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.772       0.75      0.803      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/300      4.54G      1.796      1.252      1.879         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.766      0.762      0.804      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/300      4.52G      1.806      1.263       1.88         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.8s
#                    all        844        959      0.763      0.772      0.803      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/300      4.54G      1.788      1.245      1.867         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.757      0.766      0.799       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/300      4.54G      1.791      1.258      1.885         30        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.768      0.759      0.801      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/300      4.54G      1.783      1.259      1.864         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.787      0.733      0.801      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/300      4.54G      1.799      1.244      1.873         25        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.775      0.732      0.795      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/300      4.54G      1.766      1.226      1.854         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.761      0.749      0.797      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/300      4.54G       1.75      1.224      1.848         18        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.779      0.732      0.794      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/300      4.54G      1.778      1.238      1.869         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.753       0.75      0.797      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/300      4.54G      1.785      1.245       1.86         17        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.747      0.767        0.8      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/300      4.54G      1.773      1.246      1.852         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.754      0.761      0.801      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/300      4.54G      1.761      1.206      1.846         24        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.746      0.764        0.8      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/300      4.52G      1.753        1.2      1.853         22        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.756      0.757      0.801      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/300      4.54G      1.754      1.226      1.848         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all        844        959       0.76      0.765      0.802      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/300      4.54G      1.739        1.2      1.836         19        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.752      0.768      0.801      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     151/300      4.54G      1.751      1.209      1.845         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.763      0.752      0.802      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     152/300      4.54G      1.743      1.182       1.84         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.777      0.742      0.806      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     153/300      4.54G      1.714       1.18      1.819         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959        0.8      0.725      0.803      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     154/300      4.54G      1.729      1.169      1.832         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959       0.77      0.748        0.8      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     155/300      4.54G      1.752      1.191      1.832         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.771      0.765      0.803      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     156/300      4.54G      1.735       1.18      1.829         26        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959       0.77      0.765      0.807      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     157/300      4.54G      1.708      1.149      1.819         12        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.768      0.772      0.806      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     158/300      4.54G       1.71      1.165      1.817         21        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.7it/s 7.2s
#                    all        844        959      0.775      0.756      0.809      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     159/300      4.52G      1.706      1.167      1.808         15        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.772      0.762      0.808      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     160/300      4.54G      1.727      1.167       1.83         27        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.785      0.762      0.811      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     161/300      4.52G      1.728      1.169      1.822         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all        844        959      0.782      0.763      0.813      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     162/300      4.54G      1.704      1.174      1.813         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.771      0.767      0.811      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     163/300      4.52G      1.704      1.147       1.81         13        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.803      0.734      0.808      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     164/300      4.54G      1.717      1.158      1.813         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959      0.791      0.748      0.811      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     165/300      4.54G      1.679      1.143      1.791         20        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.0s
#                    all        844        959      0.786      0.752       0.81      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     166/300      4.52G      1.691      1.131      1.801         23        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 7.0s
#                    all        844        959       0.77      0.762       0.81      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     167/300      4.54G      1.704      1.133      1.811         36        640: 100% ━━━━━━━━━━━━ 273/273 3.7it/s 1:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all        844        959      0.795       0.74       0.81      0.444
# EarlyStopping: Training stopped early as no improvement observed in last 40 epochs. Best results observed at epoch 127, best model saved as best.pt.
# To update EarlyStopping(patience=40) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 167 epochs completed in 3.772 hours.
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/last.pt, 5.6MB
# Optimizer stripped from /kaggle/working/runs/detect/train/weights/best.pt, 5.6MB
#
# Validating /kaggle/working/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.116 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLOv12n-carafe summary (fused): 163 layers, 2,609,455 parameters, 0 gradients, 7.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 3.5it/s 7.8s
#                    all        844        959      0.801      0.735       0.81      0.461
#                 Broken        170        170      0.912      0.941      0.963      0.685
#                Chipped        154        162      0.854      0.648      0.755      0.358
#              Scratched        214        217      0.799      0.587      0.726       0.34
#            Severe_Rust        167        210      0.663      0.629      0.719      0.423
#               Tip_Wear        162        200      0.777      0.871      0.887      0.497
# Speed: 0.2ms preprocess, 4.4ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train

# %% [markdown]
# # 6. Visualize kết quả

# %%
def visualize_training_loss(results_path):
    results_csv = Path(results_path) / "results.csv"
    df = pd.read_csv(results_csv)
    last_row = df.iloc[-1]
    final_metrics = {
            'mAP50': last_row.get('metrics/mAP50(B)', 0),
            'mAP50_95': last_row.get('metrics/mAP50-95(B)', 0),
            'precision': last_row.get('metrics/precision(B)', 0),
            'recall': last_row.get('metrics/recall(B)', 0),
            'box_loss': last_row.get('val/box_loss', 0),
            'cls_loss': last_row.get('val/cls_loss', 0),
            'dfl_loss': last_row.get('val/dfl_loss', 0)
        }
    
    # In kết quả cuối cùng
    print(f"\n📊 Training Results:")
    print(f"   🎯 mAP50: {final_metrics['mAP50']:.4f}")
    print(f"   🎯 mAP50-95: {final_metrics['mAP50_95']:.4f}")
    print(f"   🎯 Precision: {final_metrics['precision']:.4f}")
    print(f"   🎯 Recall: {final_metrics['recall']:.4f}")
    print(f"   📦 Box loss: {final_metrics['box_loss']:.4f}")
    print(f"   🏷️  Cls loss: {final_metrics['cls_loss']:.4f}")
    print(f"   🎯 DFL loss: {final_metrics['dfl_loss']:.4f}")

    fig, axes = plt.subplots(2, 3, figsize=(18, 12))
    metrics = [
        ('train/box_loss', 'val/box_loss', 'Box Loss'),
        ('train/cls_loss', 'val/cls_loss', 'Classification Loss'),
        ('train/dfl_loss', 'val/dfl_loss', 'DFL Loss')
    ]
    for idx, (train_metric, val_metric, title) in enumerate(metrics):
        ax = axes[0, idx]
        if train_metric in df.columns:
            ax.plot(df['epoch'], df[train_metric], label='Train', color='blue')
        if val_metric in df.columns:
            ax.plot(df['epoch'], df[val_metric], label='Val', color='red')
        ax.set_title(title, fontweight='bold')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Loss')
        ax.legend()
        ax.grid(True, alpha=0.3)
    metric_plots = [
        ('metrics/mAP50(B)', 'mAP50'),
        ('metrics/precision(B)', 'Precision'),
        ('metrics/recall(B)', 'Recall')
    ]
    
    for idx, (metric, title) in enumerate(metric_plots):
        ax = axes[1, idx]
        if metric in df.columns:
            ax.plot(df['epoch'], df[metric], color='green')
            ax.set_title(title, fontweight='bold')
            ax.set_xlabel('Epoch')
            ax.set_ylabel(title)
            ax.grid(True, alpha=0.3)
    plt.show()
    return final_metrics

final_metrics = visualize_training_loss('/kaggle/working/runs/detect/train')
# Out:
# 📊 Training Results:
#    🎯 mAP50: 0.8098
#    🎯 mAP50-95: 0.4443
#    🎯 Precision: 0.7945
#    🎯 Recall: 0.7398
#    📦 Box loss: 1.9992
#    🏷️  Cls loss: 1.0414
#    🎯 DFL loss: 2.0875

# %% [markdown]
# # 7. Các biểu đồ đánh giá

# %%
from IPython.display import Image, display

# Đường dẫn tới thư mục train
folder_path = '/kaggle/working/runs/detect/train/'

print("--- Confusion Matrix ---")
display(Image(filename=folder_path + 'confusion_matrix.png', width=1000))
print("--- PR Curve ---")
display(Image(filename=folder_path + 'BoxPR_curve.png', width=1000))
display(Image(filename=folder_path + 'BoxP_curve.png', width=1000))
display(Image(filename=folder_path + 'BoxR_curve.png', width=1000))

print("--- Loss & Metrics (Results) ---")
display(Image(filename=folder_path + 'results.png', width=1000))
# Out:
# --- Confusion Matrix ---
# --- PR Curve ---
# --- Loss & Metrics (Results) ---

# %% [markdown]
# # 8. Dự đoán

# %%
def predict_and_visualize(model_path, test_images_dir, num_samples=8, conf_threshold=0.5):
    model = YOLO(model_path)
    test_path = Path(test_images_dir)
    image_files = list(test_path.glob("*.jpg"))
    image_files = random.sample(image_files, min(num_samples, len(image_files)))
    NUM_CLASSES=5

    cols = min(4, len(image_files))
    rows = (len(image_files) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(cols*4, rows*3))

    if len(image_files) == 1:
        axes = np.array([axes])
    else:
        axes = axes.flatten()

    total_detections = 0
    class_counts = Counter()
    confidences = []

    for idx, img_path in enumerate(image_files):
        ax = axes[idx] if len(image_files) > 1 else axes
        img = cv2.imread(str(img_path))
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = model(str(img_path), conf=conf_threshold, verbose=False)
        detections = 0
        for result in results:
            if result.boxes is not None:
                for box in result.boxes:
                    detections += 1
                    total_detections += 1
                    
                    # Get box coordinates
                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                    conf = box.conf[0].cpu().numpy()
                    cls_id = int(box.cls[0].cpu().numpy())
                    
                    confidences.append(conf)
                    class_counts[cls_id] += 1
                    
                    # Draw bounding box
                    color = plt.cm.hsv(cls_id / NUM_CLASSES
                                      )[:3]
                    rect = patches.Rectangle(
                        (x1, y1), x2 - x1, y2 - y1,
                        linewidth=2, edgecolor=color, facecolor='none'
                    )
                    ax.add_patch(rect)
                    
                    # Add label
                    label = f"{CLASS_NAMES[cls_id]}: {conf:.2f}"
                    ax.text(x1, y1 - 5, label, 
                            bbox=dict(boxstyle='round,pad=0.3', facecolor=color, alpha=0.7),
                            fontsize=8, color='white', fontweight='bold')
        
        ax.imshow(img_rgb)
        ax.set_title(f"{img_path.name}\n{detections} detections", fontsize=10)
        ax.axis('off')

        # Hide unused axes
    for idx in range(len(image_files), len(axes)):
        axes[idx].axis('off')
    plt.show()
    
    # Print statistics
    print(f"\n📊 Detection Summary:")
    print(f"   📷 Images: {len(image_files)}")
    print(f"   🎯 Detections: {total_detections}")
    print(f"   📈 Avg per image: {total_detections/len(image_files):.1f}")
    print(f"   📊 Avg confidence: {np.mean(confidences):.3f}" if confidences else "   📊 Avg confidence: N/A")
    print(f"   📊 Max confidence: {np.max(confidences):.3f}" if confidences else "   📊 Max confidence: N/A")
    
    print(f"\n🏷️  Class Distribution:")
    for cls_id, count in class_counts.most_common():
        print(f"   {CLASS_NAMES[cls_id]}: {count}")
    
    return {
        'total_detections': total_detections,
        'class_counts': dict(class_counts),
        'avg_confidence': np.mean(confidences) if confidences else 0
    }

prediction_results = predict_and_visualize(
    model_path='/kaggle/working/runs/detect/train/weights/best.pt',
    test_images_dir=str(DATASET_PATH / 'test' / 'Bright_Field' /'images'),
    num_samples=8,
    conf_threshold=0.5
)
# Out:
# 📊 Detection Summary:
#    📷 Images: 8
#    🎯 Detections: 13
#    📈 Avg per image: 1.6
#    📊 Avg confidence: 0.688
#    📊 Max confidence: 0.815
#
# 🏷️  Class Distribution:
#    Broken: 4
#    Severe_Rust: 3
#    Scratched: 3
#    Chipped: 2
#    Tip_Wear: 1

# %%
def predict_and_visualize(model_path, test_images_dir, num_samples=8, conf_threshold=0.5):
    model = YOLO(model_path)
    test_path = Path(test_images_dir)
    image_files = list(test_path.glob("*.jpg"))
    image_files = random.sample(image_files, min(num_samples, len(image_files)))
    NUM_CLASSES=5

    cols = min(4, len(image_files))
    rows = (len(image_files) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(cols*4, rows*3))

    if len(image_files) == 1:
        axes = np.array([axes])
    else:
        axes = axes.flatten()

    total_detections = 0
    class_counts = Counter()
    confidences = []

    for idx, img_path in enumerate(image_files):
        ax = axes[idx] if len(image_files) > 1 else axes
        img = cv2.imread(str(img_path))
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = model(str(img_path), conf=conf_threshold, verbose=False)
        detections = 0
        for result in results:
            if result.boxes is not None:
                for box in result.boxes:
                    detections += 1
                    total_detections += 1
                    
                    # Get box coordinates
                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                    conf = box.conf[0].cpu().numpy()
                    cls_id = int(box.cls[0].cpu().numpy())
                    
                    confidences.append(conf)
                    class_counts[cls_id] += 1
                    
                    # Draw bounding box
                    color = plt.cm.hsv(cls_id / NUM_CLASSES)[:3]
                    rect = patches.Rectangle(
                        (x1, y1), x2 - x1, y2 - y1,
                        linewidth=2, edgecolor=color, facecolor='none'
                    )
                    ax.add_patch(rect)
                    
                    # Add label
                    label = f"{CLASS_NAMES[cls_id]}: {conf:.2f}"
                    ax.text(x1, y1 - 5, label, 
                            bbox=dict(boxstyle='round,pad=0.3', facecolor=color, alpha=0.7),
                            fontsize=8, color='white', fontweight='bold')
        
        ax.imshow(img_rgb)
        ax.set_title(f"{img_path.name}\n{detections} detections", fontsize=10)
        ax.axis('off')

        # Hide unused axes
    for idx in range(len(image_files), len(axes)):
        axes[idx].axis('off')
    plt.show()
    
    # Print statistics
    print(f"\n📊 Detection Summary:")
    print(f"   📷 Images: {len(image_files)}")
    print(f"   🎯 Detections: {total_detections}")
    print(f"   📈 Avg per image: {total_detections/len(image_files):.1f}")
    print(f"   📊 Avg confidence: {np.mean(confidences):.3f}" if confidences else "   📊 Avg confidence: N/A")
    print(f"   📊 Max confidence: {np.max(confidences):.3f}" if confidences else "   📊 Max confidence: N/A")
    
    print(f"\n🏷️  Class Distribution:")
    for cls_id, count in class_counts.most_common():
        print(f"   {CLASS_NAMES[cls_id]}: {count}")
    
    return {
        'total_detections': total_detections,
        'class_counts': dict(class_counts),
        'avg_confidence': np.mean(confidences) if confidences else 0
    }

prediction_results = predict_and_visualize(
    model_path='/kaggle/working/runs/detect/train/weights/best.pt',
    test_images_dir=str(DATASET_PATH / 'test' / 'Dark_Field' /'images'),
    num_samples=8,
    conf_threshold=0.5
)
# Out:
# 📊 Detection Summary:
#    📷 Images: 8
#    🎯 Detections: 4
#    📈 Avg per image: 0.5
#    📊 Avg confidence: 0.704
#    📊 Max confidence: 0.844
#
# 🏷️  Class Distribution:
#    Scratched: 2
#    Broken: 1
#    Tip_Wear: 1

# %% [markdown]
# # 9. Đánh giá mô hình trên tập test

# %%
# 10. ĐÁNH GIÁ MÔ HÌNH TRÊN TEST SET
# ============================================================
from ultralytics import YOLO
model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')  

def evaluate_model(model):    
    # Chạy validation
    metrics = model.val(data=str(data_yaml_path), split='test')

    # 1. Lấy F1-score (thường lấy tại index của confidence threshold ~0.5)
    # metrics.box.f1 trả về mảng F1 cho mỗi class
    f1_scores = metrics.box.f1
    mean_f1 = f1_scores.mean()

    # 2. Tính toán FPS
    # speed_stats bao gồm: 'preprocess', 'inference', 'loss', 'postprocess'
    speed = metrics.speed
    latency_per_img = speed['preprocess'] + speed['inference'] + speed['postprocess']
    fps = 1000 / latency_per_img

    print(f"\n📊 Evaluation Results:")
    print(f"   🎯 Mean F1-Score: {mean_f1:.4f}")
    print(f"   ⚡ FPS: {fps:.2f} ({latency_per_img:.2f} ms/ảnh)")

    # 3. In F1 per Class
    print(f"\n📈 F1 per Class:")
    # Sử dụng metrics.names để đảm bảo mapping chính xác
    for i, class_id in enumerate(metrics.ap_class_index):
        class_name = model.names[class_id]
        print(f"   🔹 {class_name}: {f1_scores[i]:.4f}")

    return {
        "mean_f1": mean_f1,
        "fps": fps
    }
data_yaml_path='data.yaml'
evaluate_model(model)
# Out:
# Ultralytics 8.4.116 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLOv12n-carafe summary (fused): 163 layers, 2,609,455 parameters, 0 gradients, 7.4 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.4±0.9 ms, read: 0.8±0.3 MB/s, size: 10.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format/test/Bright_Field/labels... 546 images, 158 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 704/704 241.8it/s 2.9s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/lmgiathnh/data-after-handle/data_convert_yolo_format/test/Bright_Field is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 44/44 5.3it/s 8.3s
#                    all        704        758      0.773      0.764      0.814      0.442
#                 Broken        128        128      0.884      0.895      0.943      0.621
#                Chipped        101        105      0.792      0.829      0.837      0.436
#              Scratched        199        203      0.741      0.631      0.721       0.34
#            Severe_Rust        173        235      0.722       0.64      0.726      0.347
#               Tip_Wear         87         87      0.725      0.828      0.844      0.468
# Speed: 1.2ms preprocess, 6.6ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
#
# 📊 Evaluation Results:
#    🎯 Mean F1-Score: 0.7665
#    ⚡ FPS: 113.21 (8.83 ms/ảnh)
#
# 📈 F1 per Class:
#    🔹 Broken: 0.8897
#    🔹 Chipped: 0.8097
#    🔹 Scratched: 0.6813
#    🔹 Severe_Rust: 0.6784
#    🔹 Tip_Wear: 0.7731
# {'mean_f1': np.float64(0.766459236856734), 'fps': 113.21215071587001}

# %%
from ultralytics import YOLO

# 1. Load model đã train của bạn
model = YOLO('/Users/mac/Detect_Drill_Bit/Models_After_Handle_Data/yolov12_after_aug/results/runs/detect/train/weights/best.pt')

# 2. Chạy validation và xuất JSON
metrics = model.val(
    data='/Users/mac/Detect_Drill_Bit/data/data_convert_yolo_format/data.yaml',
    split='val',
    save_json=True,
    device="mps"
)
# Out:
# Ultralytics 8.4.103 🚀 Python-3.11.9 torch-2.13.0 MPS (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,557,703 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 66.5±29.3 MB/s, size: 11.4 KB)
# val: Scanning /Users/mac/Detect_Drill_Bit/data/data_convert_yolo_format/valid/labels... 706 images, 138 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 844/844 7.3Kit/s 0.1s0.1s
# val: New cache created: /Users/mac/Detect_Drill_Bit/data/data_convert_yolo_format/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 53/53 3.2it/s 16.8s0.3s
#                    all        844        959      0.785      0.741      0.812      0.455
#                 Broken        170        170      0.914      0.938      0.965      0.667
#                Chipped        154        162      0.806      0.636       0.72      0.342
#              Scratched        214        217      0.765      0.539        0.7      0.335
#            Severe_Rust        167        210      0.664      0.716      0.786       0.44
#               Tip_Wear        162        200      0.775      0.875       0.89      0.493
# Speed: 0.4ms preprocess, 8.2ms inference, 0.0ms loss, 4.1ms postprocess per image
# Saving /Users/mac/Downloads/product-tag-suggester/runs/detect/val-6/predictions.json...
# Results saved to /Users/mac/Downloads/product-tag-suggester/runs/detect/val-6

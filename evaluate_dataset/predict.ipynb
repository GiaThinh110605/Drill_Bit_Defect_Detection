# %%
from ultralytics import YOLO

# 1. Load model đã train của bạn
model = YOLO('/Users/mac/Detect_Drill_Bit/Models_After_Handle_Data/yolov12_after_aug/results/runs/detect/train/weights/best.pt')

# 2. Chạy validation và xuất JSON
metrics = model.val(
    data='/Users/mac/Detect_Drill_Bit/data_convert_yolo_format/data.yaml',
    split='val',
    save_json=True,
    device="mps"
)
# Out:
# Ultralytics 8.4.103 🚀 Python-3.11.9 torch-2.13.0 MPS (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,557,703 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.0 ms, read: 100.1±30.5 MB/s, size: 11.3 KB)
# val: Scanning /Users/mac/Detect_Drill_Bit/data_convert_yolo_format/valid/labels.cache... 706 images, 138 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 844/844 160.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 53/53 3.4it/s 15.7s0.3s
#                    all        844        959      0.806      0.762      0.822      0.454
#                 Broken        170        170      0.949      0.976      0.987      0.667
#                Chipped        154        162      0.824      0.667      0.753      0.352
#              Scratched        214        217      0.784      0.608       0.74      0.341
#            Severe_Rust        167        210      0.684      0.705      0.745      0.418
#               Tip_Wear        162        200      0.788      0.855      0.885      0.492
# Speed: 0.3ms preprocess, 7.9ms inference, 0.0ms loss, 3.9ms postprocess per image
# Saving /Users/mac/Downloads/product-tag-suggester/runs/detect/val-3/predictions.json...
# Results saved to /Users/mac/Downloads/product-tag-suggester/runs/detect/val-3

# %%
from ultralytics import YOLO

# 1. Load model đã train của bạn
model = YOLO('/Users/mac/Detect_Drill_Bit/Models_After_Handle_Data/yolov12_before_aug/results/runs/detect/train/weights/best.pt')

# 2. Chạy validation và xuất JSON
metrics = model.val(
    data='/Users/mac/Detect_Drill_Bit/data_convert_yolo_format/data.yaml',
    split='val',
    save_json=True
)
# Out:
# Ultralytics 8.4.103 🚀 Python-3.11.9 torch-2.13.0 CPU (Apple M4)
# YOLOv12n summary (fused): 159 layers, 2,557,703 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.2±0.1 ms, read: 78.2±7.2 MB/s, size: 11.3 KB)
# val: Scanning /Users/mac/Detect_Drill_Bit/data_convert_yolo_format/valid/labels.cache... 706 images, 138 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 844/844 168.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 53/53 3.5s/it 3:073.6ss
#                    all        844        959      0.762      0.739      0.801      0.442
#                 Broken        170        170      0.856      0.941      0.962      0.653
#                Chipped        154        162      0.792      0.636      0.724      0.353
#              Scratched        214        217      0.725      0.572      0.701      0.309
#            Severe_Rust        167        210      0.653      0.686      0.746      0.405
#               Tip_Wear        162        200      0.783       0.86      0.871       0.49
# Speed: 0.5ms preprocess, 218.4ms inference, 0.0ms loss, 0.2ms postprocess per image
# Saving /Users/mac/Downloads/product-tag-suggester/runs/detect/val/predictions.json...
# Results saved to /Users/mac/Downloads/product-tag-suggester/runs/detect/val
